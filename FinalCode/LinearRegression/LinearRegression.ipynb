# %% [markdown]
# # Detection of Present Bias in MFA

# %% [markdown]
# ### Focused on Demographic Factors

# %%
# import the libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Import the dataset
data = pd.read_csv("Present Bias Conditions DF.csv")

data
# Out:
#      Age Group  Gender  Education  Ethnicity  MFA Familiarity Count  \
# 0            3       0          5          4                      4
# 1            2       0          5          5                      6
# 2            2       1          3          5                      4
# 3            2       2          3          1                      5
# 4            1       2          5          5                      5
# ..         ...     ...        ...        ...                    ...
# 181          1       0          5          5                      3
# 182          1       2          3          5                      3
# 183          1       0          4          5                      6
# 184          4       2          4          5                      6
# 185          2       0          4          1                      6
#
#      Security Beliefs  Security Importance  Quick Log In Importance  \
# 0                   2                   10                        9
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age Group                      186 non-null    int64
#  1   Gender                         186 non-null    int64
#  2   Education                      186 non-null    int64
#  3   Ethnicity                      186 non-null    int64
#  4   MFA Familiarity Count          186 non-null    int64
#  5   Security Beliefs               186 non-null    int64
#  6   Security Importance            186 non-null    int64
#  7   Quick Log In Importance        186 non-null    int64
#  8   Log In Usability Importance    186 non-null    int64
#  9   Log In Convenience Importance  186 non-null    int64
#  10  Log In Satisfaction            186 non-null    int64
#  11  MFA Opt In Frequency           186 non-null    int64
# ...

# %%
data.describe()
# Out:
#         Age Group      Gender   Education   Ethnicity  MFA Familiarity Count  \
# count  186.000000  186.000000  186.000000  186.000000             186.000000
# mean     1.677419    0.709677    3.913978    2.725806               4.596774
# std      0.937637    0.953862    0.937575    1.861438               1.312637
# min      1.000000    0.000000    1.000000    0.000000               1.000000
# 25%      1.000000    0.000000    3.000000    1.000000               4.000000
# 50%      1.000000    0.000000    4.000000    2.000000               5.000000
# 75%      2.000000    2.000000    5.000000    5.000000               6.000000
# max      6.000000    2.000000    5.000000    5.000000               6.000000
#
#        Security Beliefs  Security Importance  Quick Log In Importance  \
# count        186.000000           186.000000               186.000000
# mean           1.913978             9.365591                 8.806452
# ...

# %%
data.columns
# Out:
# Index(['Age Group', 'Gender', 'Education', 'Ethnicity',
#        'MFA Familiarity Count', 'Security Beliefs', 'Security Importance',
#        'Quick Log In Importance', 'Log In Usability Importance',
#        'Log In Convenience Importance', 'Log In Satisfaction',
#        'MFA Opt In Frequency', 'Present Bias'],
#       dtype='object')

# %%
sns.pairplot(data)

# %%
# distribution of the target
sns.distplot(data['MFA Opt In Frequency'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MFA Opt In Frequency', ylabel='Density'>

# %%
sns.set(rc = {'figure.figsize':(15,10)})
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### DEMO EDA

# %%
demo_eda = data[['Age Group','Gender', 'Education','Ethnicity','Security Beliefs' , 'Security Importance', 'MFA Opt In Frequency', 'Present Bias']].copy()

demo_eda.head()
# Out:
#    Age Group  Gender  Education  Ethnicity  Security Beliefs  \
# 0          3       0          5          4                 2
# 1          2       0          5          5                 2
# 2          2       1          3          5                 2
# 3          2       2          3          1                 2
# 4          1       2          5          5                 2
#
#    Security Importance  MFA Opt In Frequency  Present Bias
# 0                   10                     2             1
# 1                    7                     1             1
# 2                    6                     1             1
# 3                   10                     2             0
# 4                   10                     2             0

# %%
sns.set(rc = {'figure.figsize':(15,10)})
sns.heatmap(demo_eda.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# distribution of the target
from scipy.stats import norm

sns.distplot(demo_eda['Present Bias'], norm_hist = True, fit=norm)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Present Bias', ylabel='Density'>

# %% [markdown]
# #### we can expect our linear regression model to be around a density of 0.833. we will compare our expected value vs. the expected value after the linear regression algorithm has been performed

# %% [markdown]
# ### Linear Regression Model

# %%
X = data[['Age Group', 'Gender', 'Education', 'Ethnicity']]

# %%
y = data['Present Bias']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state =101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# print the intercept
print(lm.intercept_)
# Out:
# 0.8941355951282093

# %% [markdown]
# ####  0.894135595128209 intercept value was the actual, where the expected was around 0.833 therefore there was some error making predictions based on the data provided

# %%
lm.coef_
# Out:
# array([-0.00448825, -0.02786488, -0.0516049 ,  0.00045469])

# %%
X_train.columns
# Out:
# Index(['Age Group', 'Gender', 'Education', 'Ethnicity'], dtype='object')

# %%
cdf = pd.DataFrame(lm.coef_,X.columns,columns=['Coeff'])

# %%
cdf
# Out:
#               Coeff
# Age Group -0.004488
# Gender    -0.027865
# Education -0.051605
# Ethnicity  0.000455

# %% [markdown]
# Interpreting the coefficients:
#
# • Holding all other features fixed, a 1 unit increase in <b>Age</b> is associated with an *decrease of 0.004488 Present Bias*.
#
# ### Look at female vs male vs... to figure out if there's a correlation
# • Holding all other features fixed, a 1 unit increase in <b>Gender</b>	is associated with an *decrease of 0.027865 Present Bias*.
#
# • Holding all other features fixed, a 1 unit increase in <b>Education</b>	is associated with an *decrease of 0.060259 Present Bias*.
#
# • Holding all other features fixed, a 1 unit increase in <b>Log In Convenience Importance</b> is associated with an *increase of 0.051605 Present Bias*.
#
# ### Look at ethnicity correlations
# • Holding all other features fixed, a 1 unit increase in <b>Ethnicity</b>	is associated with an *increase of 0.000455 Present Bias*.

# %%
predictions = lm.predict(X_test)
predictions # predictions of our model for Present Bias
# Out:
# array([0.68137632, 0.56919002, 0.67919418, 0.62940803, 0.73528733,
#        0.62528317, 0.62758928, 0.62749797, 0.56470177, 0.62346441,
#        0.63207752, 0.63207752, 0.67516062, 0.57680245, 0.73710608,
#        0.68550118, 0.62355572, 0.73528733, 0.67955756, 0.68137632,
#        0.68550118, 0.61630667, 0.73528733, 0.68001225, 0.67919418,
#        0.73298122, 0.61181842, 0.68413711, 0.68368243, 0.62804396,
#        0.73528733, 0.73710608, 0.62758928, 0.62310103, 0.62795266,
#        0.68092163, 0.63207752, 0.67203644, 0.62795266, 0.67239982,
#        0.68137632, 0.57816651, 0.68413711, 0.62940803, 0.63207752,
#        0.68137632, 0.61145504])

# %%
plt.scatter(y_test,predictions)

# %% [markdown]
# #### Residual Histogram

# %%
sns.displot((y_test-predictions), bins=50, height=6, aspect=2);

# %% [markdown]
# ## Regression Evaluation Metrics
#
#
# Here are three common evaluation metrics for regression problems:
#
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
# Comparing these metrics:
#
# - **MAE** is the easiest to understand, because it's the average error.
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# All of these are **loss functions**, because we want to minimize them.

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.446977351128437
# MSE: 0.2238654089930266
# RMSE: 0.4731441735803439

# %% [markdown]
# #### MSE is the average squared distance between the observed and predicted values. A perfect model would result in a MSE value of zero.

# %%
lm.score(X_test, y_test)
# Out:
# 0.002986515190331329

# %%
#Normalizing the data

# %%
from sklearn import preprocessing

# %%
norm_demo = preprocessing.normalize(demo_eda)

norm_demo
# Out:
# array([[0.23791548, 0.        , 0.39652579, ..., 0.79305159, 0.15861032,
#         0.07930516],
#        [0.19156526, 0.        , 0.47891314, ..., 0.6704784 , 0.09578263,
#         0.09578263],
#        [0.22222222, 0.11111111, 0.33333333, ..., 0.66666667, 0.11111111,
#         0.11111111],
#        ...,
#        [0.08137885, 0.        , 0.32551538, ..., 0.81378846, 0.16275769,
#         0.08137885],
#        [0.30323922, 0.15161961, 0.30323922, ..., 0.75809804, 0.22742941,
#         0.        ],
#        [0.22941573, 0.        , 0.45883147, ..., 0.80295507, 0.11470787,
#         0.11470787]])

# %% [markdown]
# ### K Means EDA (Exploratory Data Analysis)

# %%
sns.lmplot(x = 'Age Group', y = 'Security Importance', data = data, hue= 'Present Bias', fit_reg = False, palette = 'RdPu', height=6, aspect=1)

# %%
sns.lmplot(x = 'Gender', y = 'Security Importance', data = data, hue= 'Present Bias', fit_reg = False, palette = 'RdPu', height=6, aspect=1)

# %%
sns.lmplot(x = 'Education', y = 'Security Importance', data = data, hue= 'Present Bias', fit_reg = False, palette = 'RdPu', height=6, aspect=1)

# %%
sns.lmplot(x = 'Ethnicity', y = 'Security Importance', data = data, hue= 'Present Bias', fit_reg = False, palette = 'RdPu', height=6, aspect=1)

# %% [markdown]
# #### Present Bias: Blue = 0, Orange =1 OR Pink =0, Purple = 1

# %%
demo_df = data[['Age Group','Gender', 'Education','Ethnicity', 'Security Importance', 'MFA Opt In Frequency', 'Present Bias']].copy()

demo_df.head()
# Out:
#    Age Group  Gender  Education  Ethnicity  Security Importance  \
# 0          3       0          5          4                   10
# 1          2       0          5          5                    7
# 2          2       1          3          5                    6
# 3          2       2          3          1                   10
# 4          1       2          5          5                   10
#
#    MFA Opt In Frequency  Present Bias
# 0                     2             1
# 1                     1             1
# 2                     1             1
# 3                     2             0
# 4                     2             0

# %%
g = sns.FacetGrid(demo_df, hue= 'Present Bias', palette = 'dark', height=6, aspect=2)

g = g.map(plt.hist, 'MFA Opt In Frequency', bins=20, alpha=0.8)

# %%
g = sns.FacetGrid(demo_df, hue= 'Present Bias', palette = 'dark', height=6, aspect=2)

g = g.map(plt.hist, 'Security Importance', bins=20, alpha=0.8)

# %% [markdown]
# #### Present Bias: Blue = 0, Orange =1 OR Pink =0, Purple = 1

# %%
g = sns.FacetGrid(demo_df, hue= 'Present Bias', palette = 'dark', height=6, aspect=2)

g = g.map(plt.hist, 'Age Group', bins=20, alpha=0.7)

# %% [markdown]
# #### Present Bias: Blue = 0, Orange =1 OR Pink =0, Purple = 1

# %%
g = sns.FacetGrid(demo_df, hue= 'Present Bias', palette = 'dark', height=6, aspect=2)

g = g.map(plt.hist, 'Gender', bins=20, alpha=0.5)

# %% [markdown]
# #### Present Bias: Blue = 0, Orange =1 OR Pink =0, Purple = 1

# %%
g = sns.FacetGrid(demo_df, hue= 'Present Bias', palette = 'dark', height=6, aspect=2)

g = g.map(plt.hist, 'Education', bins=20, alpha=0.5)

# %%
g = sns.FacetGrid(demo_df, hue= 'Present Bias', palette = 'dark', height=6, aspect=2)

g = g.map(plt.hist, 'Ethnicity', bins=20, alpha=0.5)

# %% [markdown]
# ## KMeans Model

# %%
#Now we are going to create the labels
#import KMeans from SciKit Learn

from sklearn.cluster import KMeans

# %%
#Create an instance of a K Means model with 2 clusters

# %%
kmeans = KMeans(n_clusters=2)

# %%
#Fit the model to all the data except for the Present Bias label

# %%
kmeans.fit(demo_df.drop('Present Bias', axis =1))
# Out:
# KMeans(n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[1.94594595, 0.90540541, 3.83783784, 4.94594595, 9.25675676,
#         1.77027027],
#        [1.5       , 0.58035714, 3.96428571, 1.25892857, 9.4375    ,
#         1.94642857]])

# %% [markdown]
# ### KMeans Demogropahic Features Analysis

# %%
demo_df
# Out:
#      Age Group  Gender  Education  Ethnicity  Security Importance  \
# 0            3       0          5          4                   10
# 1            2       0          5          5                    7
# 2            2       1          3          5                    6
# 3            2       2          3          1                   10
# 4            1       2          5          5                   10
# ..         ...     ...        ...        ...                  ...
# 181          1       0          5          5                   10
# 182          1       2          3          5                    8
# 183          1       0          4          5                   10
# 184          4       2          4          5                   10
# 185          2       0          4          1                    7
#
#      MFA Opt In Frequency  Present Bias
# 0                       2             1
# 1                       1             1
# 2                       1             1
# ...

# %%
#confusion matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(demo_df['Present Bias'], kmeans.labels_))
print('\n')
print(classification_report(demo_df['Present Bias'], kmeans.labels_))
# Out:
# [[24 38]
#  [50 74]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.32      0.39      0.35        62
#            1       0.66      0.60      0.63       124
#
#     accuracy                           0.53       186
#    macro avg       0.49      0.49      0.49       186
# weighted avg       0.55      0.53      0.54       186

# %% [markdown]
# #### Mirco average is the precision/recall/f1-score calculated for all the classes.
#
# #### Confusion matrix: Micro avg Precision
#
# #### Macro average is the average of precision/recall/f1-score.
#
# #### Confusion matrix: Macro avg Precision
#
# #### Weighted average is just the weighted average of precision/recall/f1-score.

# %%
cf_matrix = confusion_matrix(demo_df['Present Bias'], kmeans.labels_)

# %%
import seaborn as sns
sns.heatmap(cf_matrix, annot = True, )
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
            fmt='.2%', cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Age KMeans Anaylsis

# %%
age_df = data[['Age Group','Security Importance', 'MFA Opt In Frequency', 'Present Bias']].copy()

age_df.head()
# Out:
#    Age Group  Security Importance  MFA Opt In Frequency  Present Bias
# 0          3                   10                     2             1
# 1          2                    7                     1             1
# 2          2                    6                     1             1
# 3          2                   10                     2             0
# 4          1                   10                     2             0

# %%
kmeans = KMeans(n_clusters=2)

# %%
kmeans.fit(age_df.drop('Present Bias', axis =1))
# Out:
# KMeans(n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[1.71523179, 9.85430464, 1.91390728],
#        [1.51428571, 7.25714286, 1.71428571]])

# %%
print(confusion_matrix(age_df['Present Bias'], kmeans.labels_))
print('\n')
print(classification_report(age_df['Present Bias'], kmeans.labels_))
# Out:
# [[ 49  13]
#  [102  22]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.32      0.79      0.46        62
#            1       0.63      0.18      0.28       124
#
#     accuracy                           0.38       186
#    macro avg       0.48      0.48      0.37       186
# weighted avg       0.53      0.38      0.34       186

# %% [markdown]
# ### Gender KMeans Anaylsis

# %%
gender_df = data[['Gender','Security Importance', 'MFA Opt In Frequency', 'Present Bias']].copy()

gender_df.head()
# Out:
#    Gender  Security Importance  MFA Opt In Frequency  Present Bias
# 0       0                   10                     2             1
# 1       0                    7                     1             1
# 2       1                    6                     1             1
# 3       2                   10                     2             0
# 4       2                   10                     2             0

# %%
kmeans = KMeans(n_clusters=2)

# %%
kmeans.fit(gender_df.drop('Present Bias', axis =1))
# Out:
# KMeans(n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[0.66225166, 9.85430464, 1.91390728],
#        [0.91428571, 7.25714286, 1.71428571]])

# %%
print(confusion_matrix(gender_df['Present Bias'], kmeans.labels_))
print('\n')
print(classification_report(gender_df['Present Bias'], kmeans.labels_))
# Out:
# [[ 49  13]
#  [102  22]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.32      0.79      0.46        62
#            1       0.63      0.18      0.28       124
#
#     accuracy                           0.38       186
#    macro avg       0.48      0.48      0.37       186
# weighted avg       0.53      0.38      0.34       186

# %% [markdown]
# ### Education KMeans Anaylsis

# %%
ed_df = data[['Education','Security Importance', 'MFA Opt In Frequency', 'Present Bias']].copy()

ed_df.head()
# Out:
#    Education  Security Importance  MFA Opt In Frequency  Present Bias
# 0          5                   10                     2             1
# 1          5                    7                     1             1
# 2          3                    6                     1             1
# 3          3                   10                     2             0
# 4          5                   10                     2             0

# %%
kmeans = KMeans(n_clusters=2)

# %%
kmeans.fit(ed_df.drop('Present Bias', axis =1))
# Out:
# KMeans(n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[3.9602649 , 9.85430464, 1.91390728],
#        [3.71428571, 7.25714286, 1.71428571]])

# %%
print(confusion_matrix(ed_df['Present Bias'], kmeans.labels_))
print('\n')
print(classification_report(ed_df['Present Bias'], kmeans.labels_))
# Out:
# [[ 49  13]
#  [102  22]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.32      0.79      0.46        62
#            1       0.63      0.18      0.28       124
#
#     accuracy                           0.38       186
#    macro avg       0.48      0.48      0.37       186
# weighted avg       0.53      0.38      0.34       186

# %% [markdown]
# ### Ethnicity KMeans Anaylsis

# %%
eth_df = data[['Ethnicity','Security Importance', 'MFA Opt In Frequency', 'Present Bias']].copy()

eth_df.head()
# Out:
#    Ethnicity  Security Importance  MFA Opt In Frequency  Present Bias
# 0          4                   10                     2             1
# 1          5                    7                     1             1
# 2          5                    6                     1             1
# 3          1                   10                     2             0
# 4          5                   10                     2             0

# %%
kmeans = KMeans(n_clusters=2)

# %%
kmeans.fit(eth_df.drop('Present Bias', axis =1))
# Out:
# KMeans(n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[1.25892857, 9.4375    , 1.94642857],
#        [4.94594595, 9.25675676, 1.77027027]])

# %%
print(confusion_matrix(eth_df['Present Bias'], kmeans.labels_))
print('\n')
print(classification_report(eth_df['Present Bias'], kmeans.labels_))
# Out:
# [[38 24]
#  [74 50]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.34      0.61      0.44        62
#            1       0.68      0.40      0.51       124
#
#     accuracy                           0.47       186
#    macro avg       0.51      0.51      0.47       186
# weighted avg       0.56      0.47      0.48       186

# %% [markdown]
# ### Security Importance & MFA Opt In Fequency KMeans Anaylsis

# %%
sec_mfa = data[['Security Importance', 'MFA Opt In Frequency', 'Present Bias']].copy()

sec_mfa.head()
# Out:
#    Security Importance  MFA Opt In Frequency  Present Bias
# 0                   10                     2             1
# 1                    7                     1             1
# 2                    6                     1             1
# 3                   10                     2             0
# 4                   10                     2             0

# %%
kmeans = KMeans(n_clusters=2)

# %%
kmeans.fit(sec_mfa.drop('Present Bias', axis =1))
# Out:
# KMeans(n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[7.25714286, 1.71428571],
#        [9.85430464, 1.91390728]])

# %%
print(confusion_matrix(sec_mfa['Present Bias'], kmeans.labels_))
print('\n')
print(classification_report(sec_mfa['Present Bias'], kmeans.labels_))
# Out:
# [[ 13  49]
#  [ 22 102]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.37      0.21      0.27        62
#            1       0.68      0.82      0.74       124
#
#     accuracy                           0.62       186
#    macro avg       0.52      0.52      0.50       186
# weighted avg       0.57      0.62      0.58       186

# %% [markdown]
# ### Security Importance KMeans Analysis

# %%
sec_df = data[['Security Importance', 'Present Bias']].copy()

sec_df.head()
# Out:
#    Security Importance  Present Bias
# 0                   10             1
# 1                    7             1
# 2                    6             1
# 3                   10             0
# 4                   10             0

# %%
kmeans = KMeans(n_clusters=2)

# %%
kmeans.fit(sec_df.drop('Present Bias', axis =1))
# Out:
# KMeans(n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[9.85430464],
#        [7.25714286]])

# %%
print(confusion_matrix(sec_df['Present Bias'], kmeans.labels_))
print('\n')
print(classification_report(sec_df['Present Bias'], kmeans.labels_))
# Out:
# [[ 49  13]
#  [102  22]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.32      0.79      0.46        62
#            1       0.63      0.18      0.28       124
#
#     accuracy                           0.38       186
#    macro avg       0.48      0.48      0.37       186
# weighted avg       0.53      0.38      0.34       186

# %% [markdown]
# ### MFA KMeans Analysis

# %%
mfa_df = data[['MFA Opt In Frequency', 'Present Bias']].copy()

mfa_df.head()
# Out:
#    MFA Opt In Frequency  Present Bias
# 0                     2             1
# 1                     1             1
# 2                     1             1
# 3                     2             0
# 4                     2             0

# %%
kmeans = KMeans(n_clusters=2)

# %%
kmeans.fit(mfa_df.drop('Present Bias', axis =1))
# Out:
# KMeans(n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[2.39166667],
#        [0.93939394]])

# %%
print(confusion_matrix(mfa_df['Present Bias'], kmeans.labels_))
print('\n')
print(classification_report(mfa_df['Present Bias'], kmeans.labels_))
# Out:
# [[53  9]
#  [67 57]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.44      0.85      0.58        62
#            1       0.86      0.46      0.60       124
#
#     accuracy                           0.59       186
#    macro avg       0.65      0.66      0.59       186
# weighted avg       0.72      0.59      0.59       186

# %%
trace0= go.Scatter(x = age_table[age_table.cluster ==0]['x'],
                   y = age_table[age_table.cluster ==0]['y'],
                   name = 'Cluster 1',
                   mode = 'markers',
                   marker = dict(size = 10,
                                color ='rgba(15, 152, 152, 0.5)',
                                line = dict(width = 1, color= 'rgb(0,0,0)'))
                  )

trace1= go.Scatter(x = age_table[age_table.cluster ==1]['x'],
                   y = age_table[age_table.cluster ==1]['y'],
                   name = 'Cluster 2',
                   mode = 'markers',
                   marker = dict(size = 10,
                                color ='rgba(180, 18, 180, 0.5)',
                                line = dict(width = 1, color= 'rgb(0,0,0)'))
                  )

trace2= go.Scatter(x = age_table[age_table.cluster ==2]['x'],
                   y = age_table[age_table.cluster ==2]['y'],
                   name = 'Cluster 3',
                   mode = 'markers',
                   marker = dict(size = 10,
                                color ='rgba(132, 132, 132, 0.8)',
                                line = dict(width = 1, color= 'rgb(0,0,0)'))
                  )

trace3= go.Scatter(x = age_table[age_table.cluster ==3]['x'],
                   y = age_table[age_table.cluster ==3]['y'],
                   name = 'Cluster 4',
                   mode = 'markers',
                   marker = dict(size = 10,
                                color ='rgba(122, 122, 12, 0.8)',
                                line = dict(width = 1, color= 'rgb(0,0,0)'))
                  )

trace4= go.Scatter(x = age_table[age_table.cluster ==4]['x'],
                   y = age_table[age_table.cluster ==4]['y'],
                   name = 'Cluster 5',
                   mode = 'markers',
                   marker = dict(size = 10,
                                color ='rgba(230, 20, 30, 0.5)',
                                line = dict(width = 1, color= 'rgb(0,0,0)'))
                  )

age_data = [trace0, trace1, trace2, trace3, trace4]

iplot(age_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-ae1ea09b789b> in <module>
# ----> 1 trace0= go.Scatter(x = age_table[age_table.cluster ==0]['x'],
#       2                    y = age_table[age_table.cluster ==0]['y'],
#       3                    name = 'Cluster 1',
#       4                    mode = 'markers',
#       5                    marker = dict(size = 10,
#
# NameError: name 'go' is not defined

# %%
age_table['0'] = age_table.cluster == 0
age_table.groupby('0').Type.value_counts()

# %%
kmeans = KMeans(n_clusters=5).fit(age_data)
centroids = kmeans.cluster_centers_
print(centroids)

plt.scatter(age_data['Systems Used'], age_data['Age Group'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.xlabel('Systems Used')
plt.ylabel('Age Group')
plt.show()

# %%
#Gender
age_table = df.pivot_table(index = ['Age Group'], columns = ['MFA Example Use'], values = 'MFA Example Use Numerical' )

# %%
age_table = age_table.fillna(0).reset_index()

# %%
#Education
age_table = df.pivot_table(index = ['Age Group'], columns = ['MFA Example Use'], values = 'MFA Example Use Numerical' )

# %%
age_table = age_table.fillna(0).reset_index()

# %%
#Ethnicity
age_table = df.pivot_table(index = ['Age Group'], columns = ['MFA Example Use'], values = 'MFA Example Use Numerical' )

# %%
age_table = age_table.fillna(0).reset_index()
